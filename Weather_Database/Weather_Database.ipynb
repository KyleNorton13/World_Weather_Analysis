# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key# Import the datetime module from the datetime library.

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#4. Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

   
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 753

# %%
#5 Perform an API Call with OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d30471a69fd2a3c89bb0c23c9dc6f562

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | guiglo
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | lipin bor
# Processing Record 6 of Set 1 | ancud
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | quelimane
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 1 | meadow lake
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | asau
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | wundanyi
# Processing Record 28 of Set 1 | saldanha
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | muros
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | balkanabat
# Processing Record 35 of Set 1 | plouzane
# Processing Record 36 of Set 1 | walvis bay
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | brae
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | port macquarie
# Processing Record 42 of Set 1 | santiago del estero
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | bunia
# Processing Record 50 of Set 1 | itarema
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | bubaque
# Processing Record 3 of Set 2 | padang
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | northam
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | quimper
# Processing Record 8 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | butembo
# Processing Record 11 of Set 2 | lavrentiya
# Processing Record 12 of Set 2 | ucluelet
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | catabola
# Processing Record 15 of Set 2 | samana
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | emerald
# Processing Record 18 of Set 2 | bandar-e lengeh
# Processing Record 19 of Set 2 | kihei
# Processing Record 20 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | vigevano
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | camana
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | vao
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | inzhavino
# Processing Record 33 of Set 2 | nhamunda
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | manzhouli
# Processing Record 38 of Set 2 | belaya gora
# Processing Record 39 of Set 2 | vila velha
# Processing Record 40 of Set 2 | pacific grove
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | paramonga
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | anadyr
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | banda aceh
# Processing Record 49 of Set 2 | chapais
# Processing Record 50 of Set 2 | dubbo
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | haines junction
# Processing Record 3 of Set 3 | ulaanbaatar
# Processing Record 4 of Set 3 | la rioja
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | terney
# Processing Record 7 of Set 3 | xiongzhou
# Processing Record 8 of Set 3 | wladyslawowo
# Processing Record 9 of Set 3 | morro bay
# Processing Record 10 of Set 3 | panjab
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | saint-francois
# Processing Record 17 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | bogovarovo
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | leningradskiy
# Processing Record 22 of Set 3 | matara
# Processing Record 23 of Set 3 | culfa
# Processing Record 24 of Set 3 | olinda
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 3 | lumberton
# Processing Record 30 of Set 3 | oga
# Processing Record 31 of Set 3 | plettenberg bay
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 3 | ilo
# Processing Record 35 of Set 3 | ostrovnoy
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | college station
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | vostok
# Processing Record 45 of Set 3 | nenjiang
# Processing Record 46 of Set 3 | noumea
# Processing Record 47 of Set 3 | szigetvar
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | koupela
# Processing Record 50 of Set 3 | bonavista
# Processing Record 1 of Set 4 | paamiut
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | diamantino
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | korla
# Processing Record 7 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 4 | george
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | gigmoto
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | sampit
# Processing Record 18 of Set 4 | juneau
# Processing Record 19 of Set 4 | buenos aires
# Processing Record 20 of Set 4 | warsaw
# Processing Record 21 of Set 4 | toora-khem
# Processing Record 22 of Set 4 | havoysund
# Processing Record 23 of Set 4 | bambous virieux
# Processing Record 24 of Set 4 | kedrovyy
# Processing Record 25 of Set 4 | emba
# Processing Record 26 of Set 4 | were ilu
# Processing Record 27 of Set 4 | jalu
# Processing Record 28 of Set 4 | mongoumba
# Processing Record 29 of Set 4 | castelo do piaui
# Processing Record 30 of Set 4 | kochubey
# Processing Record 31 of Set 4 | baykit
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | saint-pierre
# Processing Record 34 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | saint-georges
# Processing Record 37 of Set 4 | zaozerne
# Processing Record 38 of Set 4 | inhambane
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | phangnga
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | canitas
# City not found. Skipping...
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | severnoye
# Processing Record 45 of Set 4 | belyy yar
# Processing Record 46 of Set 4 | christchurch
# Processing Record 47 of Set 4 | benjamin constant
# Processing Record 48 of Set 4 | zhangzhou
# Processing Record 49 of Set 4 | hambantota
# Processing Record 50 of Set 4 | soyo
# Processing Record 1 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 5 | astana
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | ternate
# Processing Record 5 of Set 5 | pangkalanbuun
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 5 | arlit
# Processing Record 8 of Set 5 | karratha
# Processing Record 9 of Set 5 | miyako
# Processing Record 10 of Set 5 | areal
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | montepulciano
# Processing Record 14 of Set 5 | naraini
# Processing Record 15 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 5 | turayf
# Processing Record 17 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | maniitsoq
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | havre-saint-pierre
# Processing Record 22 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | thompson
# Processing Record 25 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 26 of Set 5 | medzev
# Processing Record 27 of Set 5 | zemaiciu naumiestis
# Processing Record 28 of Set 5 | labuhan
# Processing Record 29 of Set 5 | thinadhoo
# Processing Record 30 of Set 5 | kachug
# Processing Record 31 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 5 | salta
# Processing Record 33 of Set 5 | adolfo lopez mateos
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | kapaa
# Processing Record 36 of Set 5 | magistralnyy
# Processing Record 37 of Set 5 | praya
# Processing Record 38 of Set 5 | sibu
# Processing Record 39 of Set 5 | nisia floresta
# Processing Record 40 of Set 5 | sao joao da barra
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | coihaique
# Processing Record 43 of Set 5 | jorochito
# Processing Record 44 of Set 5 | vetluga
# Processing Record 45 of Set 5 | play cu
# City not found. Skipping...
# Processing Record 46 of Set 5 | lata
# Processing Record 47 of Set 5 | bakchar
# Processing Record 48 of Set 5 | zahnitkiv
# Processing Record 49 of Set 5 | banikoara
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | tongliao
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | bantogon
# Processing Record 4 of Set 6 | gat
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | saint-philippe
# Processing Record 7 of Set 6 | moose factory
# Processing Record 8 of Set 6 | namibe
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | broken hill
# Processing Record 11 of Set 6 | xai-xai
# Processing Record 12 of Set 6 | safakulevo
# Processing Record 13 of Set 6 | ulladulla
# Processing Record 14 of Set 6 | gbarnga
# Processing Record 15 of Set 6 | norwich
# Processing Record 16 of Set 6 | weihe
# Processing Record 17 of Set 6 | voyvozh
# Processing Record 18 of Set 6 | atlantic beach
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 20 of Set 6 | liling
# Processing Record 21 of Set 6 | cap malheureux
# Processing Record 22 of Set 6 | weiser
# Processing Record 23 of Set 6 | amahai
# Processing Record 24 of Set 6 | ndioum
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | sterling
# Processing Record 27 of Set 6 | yumen
# Processing Record 28 of Set 6 | tabuk
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | nandasmo
# Processing Record 31 of Set 6 | isla mujeres
# Processing Record 32 of Set 6 | karlskrona
# Processing Record 33 of Set 6 | clarence town
# Processing Record 34 of Set 6 | newport
# Processing Record 35 of Set 6 | bud
# Processing Record 36 of Set 6 | mitu
# Processing Record 37 of Set 6 | baruun-urt
# Processing Record 38 of Set 6 | okha
# Processing Record 39 of Set 6 | bac lieu
# Processing Record 40 of Set 6 | faro
# Processing Record 41 of Set 6 | kendari
# Processing Record 42 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | xining
# Processing Record 44 of Set 6 | mazatlan
# Processing Record 45 of Set 6 | buala
# Processing Record 46 of Set 6 | swift current
# Processing Record 47 of Set 6 | enshi
# Processing Record 48 of Set 6 | miri
# Processing Record 49 of Set 6 | zalantun
# Processing Record 50 of Set 6 | san andres
# Processing Record 1 of Set 7 | vychegodskiy
# Processing Record 2 of Set 7 | half moon bay
# Processing Record 3 of Set 7 | malangali
# Processing Record 4 of Set 7 | agdas
# Processing Record 5 of Set 7 | iquique
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | swan hill
# Processing Record 8 of Set 7 | tagusao
# Processing Record 9 of Set 7 | namie
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | monrovia
# Processing Record 12 of Set 7 | raudeberg
# Processing Record 13 of Set 7 | tautira
# Processing Record 14 of Set 7 | jiangyou
# Processing Record 15 of Set 7 | chake chake
# Processing Record 16 of Set 7 | benguela
# Processing Record 17 of Set 7 | kuusamo
# Processing Record 18 of Set 7 | campos altos
# Processing Record 19 of Set 7 | sovetskiy
# Processing Record 20 of Set 7 | ingham
# Processing Record 21 of Set 7 | north myrtle beach
# Processing Record 22 of Set 7 | torbay
# Processing Record 23 of Set 7 | izazi
# Processing Record 24 of Set 7 | qinhuangdao
# Processing Record 25 of Set 7 | bandarbeyla
# Processing Record 26 of Set 7 | mehamn
# Processing Record 27 of Set 7 | molinella
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | los llanos de aridane
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 7 | praia da vitoria
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 7 | loukhi
# Processing Record 36 of Set 7 | cheney
# Processing Record 37 of Set 7 | puerto rico
# Processing Record 38 of Set 7 | nome
# Processing Record 39 of Set 7 | peniche
# Processing Record 40 of Set 7 | imperia
# Processing Record 41 of Set 7 | alofi
# Processing Record 42 of Set 7 | carutapera
# Processing Record 43 of Set 7 | hualmay
# Processing Record 44 of Set 7 | lashio
# Processing Record 45 of Set 7 | sorong
# Processing Record 46 of Set 7 | ojinaga
# Processing Record 47 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 48 of Set 7 | monte alegre
# Processing Record 49 of Set 7 | rassvet
# Processing Record 50 of Set 7 | berlevag
# Processing Record 1 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 8 | qaqortoq
# Processing Record 3 of Set 8 | sao filipe
# Processing Record 4 of Set 8 | erzin
# Processing Record 5 of Set 8 | umm kaddadah
# Processing Record 6 of Set 8 | bani
# Processing Record 7 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 8 | buraydah
# Processing Record 9 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 8 | muroto
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | vila do maio
# Processing Record 13 of Set 8 | zolochiv
# Processing Record 14 of Set 8 | bundaberg
# Processing Record 15 of Set 8 | cidreira
# Processing Record 16 of Set 8 | arman
# Processing Record 17 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 8 | penne
# Processing Record 19 of Set 8 | beroroha
# Processing Record 20 of Set 8 | college
# Processing Record 21 of Set 8 | el badari
# City not found. Skipping...
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | kalino
# Processing Record 24 of Set 8 | ballina
# Processing Record 25 of Set 8 | seymchan
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | kita
# Processing Record 28 of Set 8 | zhuhai
# Processing Record 29 of Set 8 | kapoeta
# Processing Record 30 of Set 8 | katherine
# Processing Record 31 of Set 8 | mezhdurechenskiy
# Processing Record 32 of Set 8 | west bay
# Processing Record 33 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 34 of Set 8 | sol-iletsk
# Processing Record 35 of Set 8 | bengkulu
# Processing Record 36 of Set 8 | birjand
# Processing Record 37 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 8 | dunedin
# Processing Record 41 of Set 8 | sahiwal
# Processing Record 42 of Set 8 | cravo norte
# Processing Record 43 of Set 8 | oyem
# Processing Record 44 of Set 8 | laohekou
# Processing Record 45 of Set 8 | kaeo
# Processing Record 46 of Set 8 | mogadishu
# Processing Record 47 of Set 8 | kagalnitskaya
# Processing Record 48 of Set 8 | ahipara
# Processing Record 49 of Set 8 | cherskiy
# Processing Record 50 of Set 8 | kongolo
# Processing Record 1 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 9 | beruwala
# Processing Record 3 of Set 9 | bengbu
# Processing Record 4 of Set 9 | kuytun
# Processing Record 5 of Set 9 | yellapur
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 9 | ust-tsilma
# Processing Record 9 of Set 9 | grakhovo
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | hobyo
# Processing Record 12 of Set 9 | san felipe
# Processing Record 13 of Set 9 | aba
# Processing Record 14 of Set 9 | parksville
# Processing Record 15 of Set 9 | ukiah
# Processing Record 16 of Set 9 | saint-denis
# Processing Record 17 of Set 9 | dakar
# Processing Record 18 of Set 9 | vila franca do campo
# Processing Record 19 of Set 9 | brownsville
# Processing Record 20 of Set 9 | harper
# Processing Record 21 of Set 9 | porec
# Processing Record 22 of Set 9 | tarancon
# Processing Record 23 of Set 9 | siderno
# Processing Record 24 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 9 | port hedland
# Processing Record 28 of Set 9 | chinhoyi
# Processing Record 29 of Set 9 | goma
# Processing Record 30 of Set 9 | punta cardon
# Processing Record 31 of Set 9 | galesong
# Processing Record 32 of Set 9 | vung tau
# Processing Record 33 of Set 9 | tsumeb
# Processing Record 34 of Set 9 | port lincoln
# Processing Record 35 of Set 9 | alyangula
# Processing Record 36 of Set 9 | jibuti
# Processing Record 37 of Set 9 | palmas bellas
# Processing Record 38 of Set 9 | humen
# Processing Record 39 of Set 9 | camacha
# Processing Record 40 of Set 9 | kuchera
# Processing Record 41 of Set 9 | kilindoni
# Processing Record 42 of Set 9 | dalian
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | santiago
# Processing Record 45 of Set 9 | mirnyy
# Processing Record 46 of Set 9 | praia
# Processing Record 47 of Set 9 | nortelandia
# Processing Record 48 of Set 9 | rincon
# Processing Record 49 of Set 9 | maroantsetra
# Processing Record 50 of Set 9 | san jeronimo
# Processing Record 1 of Set 10 | winnemucca
# Processing Record 2 of Set 10 | smidovich
# Processing Record 3 of Set 10 | acajutla
# Processing Record 4 of Set 10 | jutai
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | shenjiamen
# Processing Record 7 of Set 10 | senno
# Processing Record 8 of Set 10 | betare oya
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | zilair
# Processing Record 11 of Set 10 | viedma
# Processing Record 12 of Set 10 | waipawa
# Processing Record 13 of Set 10 | bereda
# Processing Record 14 of Set 10 | rock sound
# Processing Record 15 of Set 10 | mahibadhoo
# Processing Record 16 of Set 10 | tianpeng
# Processing Record 17 of Set 10 | mizdah
# Processing Record 18 of Set 10 | rio cuarto
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | khash
# Processing Record 21 of Set 10 | khandyga
# Processing Record 22 of Set 10 | jumla
# Processing Record 23 of Set 10 | san cosme y damian
# Processing Record 24 of Set 10 | skotterud
# Processing Record 25 of Set 10 | kandrian
# Processing Record 26 of Set 10 | fairbanks
# Processing Record 27 of Set 10 | isabela
# Processing Record 28 of Set 10 | arrecife
# Processing Record 29 of Set 10 | at-bashi
# Processing Record 30 of Set 10 | sorland
# Processing Record 31 of Set 10 | ankazobe
# Processing Record 32 of Set 10 | port moresby
# Processing Record 33 of Set 10 | yulara
# Processing Record 34 of Set 10 | igra
# Processing Record 35 of Set 10 | avera
# Processing Record 36 of Set 10 | nelson bay
# Processing Record 37 of Set 10 | chiredzi
# Processing Record 38 of Set 10 | derzhavinsk
# Processing Record 39 of Set 10 | carora
# Processing Record 40 of Set 10 | saint anthony
# Processing Record 41 of Set 10 | sembe
# Processing Record 42 of Set 10 | yeppoon
# Processing Record 43 of Set 10 | gazni
# City not found. Skipping...
# Processing Record 44 of Set 10 | barcelos
# Processing Record 45 of Set 10 | reinosa
# Processing Record 46 of Set 10 | algiers
# Processing Record 47 of Set 10 | machali
# Processing Record 48 of Set 10 | lima
# Processing Record 49 of Set 10 | krasnoselkup
# Processing Record 50 of Set 10 | san cristobal
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | grindavik
# Processing Record 3 of Set 11 | norman wells
# Processing Record 4 of Set 11 | port hardy
# Processing Record 5 of Set 11 | rosarito
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | taunsa
# Processing Record 8 of Set 11 | ximei
# Processing Record 9 of Set 11 | san luis
# Processing Record 10 of Set 11 | enkoping
# Processing Record 11 of Set 11 | surt
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | tayoltita
# Processing Record 14 of Set 11 | gornopravdinsk
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | ahuimanu
# Processing Record 17 of Set 11 | zanjan
# Processing Record 18 of Set 11 | dwarka
# Processing Record 19 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 11 | khuzdar
# Processing Record 21 of Set 11 | kenai
# Processing Record 22 of Set 11 | roald
# Processing Record 23 of Set 11 | juxian
# City not found. Skipping...
# Processing Record 24 of Set 11 | te anau
# Processing Record 25 of Set 11 | buy
# Processing Record 26 of Set 11 | gua musang
# Processing Record 27 of Set 11 | viransehir
# Processing Record 28 of Set 11 | kirakira
# Processing Record 29 of Set 11 | manzanillo
# Processing Record 30 of Set 11 | loralai
# Processing Record 31 of Set 11 | orlik
# Processing Record 32 of Set 11 | garowe
# Processing Record 33 of Set 11 | puerto leguizamo
# Processing Record 34 of Set 11 | kununurra
# Processing Record 35 of Set 11 | birmitrapur
# Processing Record 36 of Set 11 | capitao poco
# Processing Record 37 of Set 11 | fort smith
# Processing Record 38 of Set 11 | leiyang
# Processing Record 39 of Set 11 | besenyotelek
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | broome
# Processing Record 43 of Set 11 | ouargaye
# Processing Record 44 of Set 11 | monchegorsk
# Processing Record 45 of Set 11 | sagar
# Processing Record 46 of Set 11 | daru
# Processing Record 47 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 11 | aleksandrov gay
# Processing Record 49 of Set 11 | malanje
# Processing Record 50 of Set 11 | kouango
# Processing Record 1 of Set 12 | belvedere marittimo
# Processing Record 2 of Set 12 | russell
# Processing Record 3 of Set 12 | meulaboh
# Processing Record 4 of Set 12 | annau
# Processing Record 5 of Set 12 | dingle
# Processing Record 6 of Set 12 | marzuq
# Processing Record 7 of Set 12 | valparaiso
# Processing Record 8 of Set 12 | ngunguru
# Processing Record 9 of Set 12 | san ignacio
# Processing Record 10 of Set 12 | oksfjord
# Processing Record 11 of Set 12 | margate
# Processing Record 12 of Set 12 | bay-khaak
# Processing Record 13 of Set 12 | gunnedah
# Processing Record 14 of Set 12 | polyarnyy
# Processing Record 15 of Set 12 | nishihara
# Processing Record 16 of Set 12 | kapuskasing
# Processing Record 17 of Set 12 | soligalich
# Processing Record 18 of Set 12 | ovsyanka
# Processing Record 19 of Set 12 | cajaruro
# Processing Record 20 of Set 12 | diego de almagro
# Processing Record 21 of Set 12 | rio gallegos
# Processing Record 22 of Set 12 | amapa
# Processing Record 23 of Set 12 | cuenca
# Processing Record 24 of Set 12 | padre bernardo
# Processing Record 25 of Set 12 | namtsy
# Processing Record 26 of Set 12 | karpathos
# Processing Record 27 of Set 12 | bowen
# Processing Record 28 of Set 12 | ziro
# Processing Record 29 of Set 12 | presque isle
# Processing Record 30 of Set 12 | loreto
# Processing Record 31 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 12 | vaitape
# Processing Record 33 of Set 12 | port blair
# Processing Record 34 of Set 12 | bilma
# Processing Record 35 of Set 12 | severomuysk
# Processing Record 36 of Set 12 | marsabit
# Processing Record 37 of Set 12 | nago
# Processing Record 38 of Set 12 | mountain home
# Processing Record 39 of Set 12 | sept-iles
# Processing Record 40 of Set 12 | bilibino
# Processing Record 41 of Set 12 | niquelandia
# Processing Record 42 of Set 12 | spornoye
# Processing Record 43 of Set 12 | cardston
# Processing Record 44 of Set 12 | mastic beach
# Processing Record 45 of Set 12 | fallon
# Processing Record 46 of Set 12 | tsiroanomandidy
# Processing Record 47 of Set 12 | labuan
# Processing Record 48 of Set 12 | iquitos
# Processing Record 49 of Set 12 | fort-shevchenko
# Processing Record 50 of Set 12 | yatou
# Processing Record 1 of Set 13 | mackay
# Processing Record 2 of Set 13 | ormara
# Processing Record 3 of Set 13 | vestmannaeyjar
# Processing Record 4 of Set 13 | columbia
# Processing Record 5 of Set 13 | namwala
# Processing Record 6 of Set 13 | graham
# Processing Record 7 of Set 13 | ambatolampy
# Processing Record 8 of Set 13 | tres arroyos
# Processing Record 9 of Set 13 | talcahuano
# Processing Record 10 of Set 13 | havelock
# Processing Record 11 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 12 of Set 13 | shimoda
# Processing Record 13 of Set 13 | esteli
# Processing Record 14 of Set 13 | nurota
# Processing Record 15 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 13 | san luis de palenque
# Processing Record 17 of Set 13 | port augusta
# Processing Record 18 of Set 13 | lubang
# Processing Record 19 of Set 13 | yankton
# Processing Record 20 of Set 13 | saint-joseph
# Processing Record 21 of Set 13 | tucupita
# Processing Record 22 of Set 13 | santa isabel
# Processing Record 23 of Set 13 | kathu
# Processing Record 24 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 13 | tezu
# Processing Record 26 of Set 13 | presidencia roque saenz pena
# Processing Record 27 of Set 13 | ust-kuyga
# Processing Record 28 of Set 13 | maraba
# Processing Record 29 of Set 13 | nioro
# Processing Record 30 of Set 13 | the valley
# Processing Record 31 of Set 13 | porto belo
# Processing Record 32 of Set 13 | erdenet
# Processing Record 33 of Set 13 | edson
# Processing Record 34 of Set 13 | beaufort
# Processing Record 35 of Set 13 | lumeje
# Processing Record 36 of Set 13 | evanston
# Processing Record 37 of Set 13 | amuntai
# Processing Record 38 of Set 13 | koumac
# Processing Record 39 of Set 13 | adrar
# Processing Record 40 of Set 13 | bastrop
# Processing Record 41 of Set 13 | stephenville
# Processing Record 42 of Set 13 | marawi
# Processing Record 43 of Set 13 | batemans bay
# Processing Record 44 of Set 13 | copalillo
# Processing Record 45 of Set 13 | sibolga
# Processing Record 46 of Set 13 | gashua
# Processing Record 47 of Set 13 | wenshang
# Processing Record 48 of Set 13 | ambon
# Processing Record 49 of Set 13 | kropachevo
# Processing Record 50 of Set 13 | milove
# Processing Record 1 of Set 14 | bria
# Processing Record 2 of Set 14 | jilib
# Processing Record 3 of Set 14 | trincomalee
# Processing Record 4 of Set 14 | san carlos de bariloche
# Processing Record 5 of Set 14 | hohhot
# Processing Record 6 of Set 14 | turkistan
# Processing Record 7 of Set 14 | denpasar
# Processing Record 8 of Set 14 | warmbad
# Processing Record 9 of Set 14 | sikea
# City not found. Skipping...
# Processing Record 10 of Set 14 | leh
# Processing Record 11 of Set 14 | batagay
# Processing Record 12 of Set 14 | itamaraca
# Processing Record 13 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 14 | sao jose dos campos
# Processing Record 15 of Set 14 | umtata
# Processing Record 16 of Set 14 | coahuayana
# Processing Record 17 of Set 14 | huarmey
# Processing Record 18 of Set 14 | fort nelson
# Processing Record 19 of Set 14 | asmara
# Processing Record 20 of Set 14 | doka
# Processing Record 21 of Set 14 | centralia
# Processing Record 22 of Set 14 | nara
# Processing Record 23 of Set 14 | villamontes
# Processing Record 24 of Set 14 | alberton
# Processing Record 25 of Set 14 | witu
# Processing Record 26 of Set 14 | punta alta
# Processing Record 27 of Set 14 | saint-leu
# Processing Record 28 of Set 14 | san vicente
# Processing Record 29 of Set 14 | strezhevoy
# Processing Record 30 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 14 | guanay
# Processing Record 32 of Set 14 | akdepe
# Processing Record 33 of Set 14 | rakhya
# City not found. Skipping...
# Processing Record 34 of Set 14 | delijan
# Processing Record 35 of Set 14 | polunochnoye
# Processing Record 36 of Set 14 | nelson
# Processing Record 37 of Set 14 | aksarka
# Processing Record 38 of Set 14 | chamba
# Processing Record 39 of Set 14 | kholmsk
# Processing Record 40 of Set 14 | richards bay
# Processing Record 41 of Set 14 | dungarpur
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | jalapa
# Processing Record 44 of Set 14 | shelabolikha
# Processing Record 45 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 14 | melilla
# Processing Record 47 of Set 14 | urumqi
# Processing Record 48 of Set 14 | seydi
# Processing Record 49 of Set 14 | evans
# Processing Record 50 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 15 | jishou
# Processing Record 2 of Set 15 | sioux lookout
# Processing Record 3 of Set 15 | chontalpa
# Processing Record 4 of Set 15 | casper
# Processing Record 5 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 15 | halifax
# Processing Record 7 of Set 15 | nagaur
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | nieuw nickerie
# Processing Record 10 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 11 of Set 15 | itoman
# Processing Record 12 of Set 15 | general roca
# Processing Record 13 of Set 15 | ostersund
# Processing Record 14 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 15 | yibin
# Processing Record 16 of Set 15 | kanye
# Processing Record 17 of Set 15 | buchanan
# Processing Record 18 of Set 15 | blind river
# Processing Record 19 of Set 15 | rudbar
# Processing Record 20 of Set 15 | aripuana
# Processing Record 21 of Set 15 | sao marcos
# Processing Record 22 of Set 15 | nazareno
# Processing Record 23 of Set 15 | sonoita
# Processing Record 24 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 15 | high level
# Processing Record 26 of Set 15 | kidal
# Processing Record 27 of Set 15 | mandalgovi
# Processing Record 28 of Set 15 | kathmandu
# Processing Record 29 of Set 15 | sheregesh
# Processing Record 30 of Set 15 | lubao
# Processing Record 31 of Set 15 | mantua
# Processing Record 32 of Set 15 | qiyang
# Processing Record 33 of Set 15 | wuwei
# Processing Record 34 of Set 15 | darasun
# Processing Record 35 of Set 15 | buritis
# Processing Record 36 of Set 15 | olafsvik
# Processing Record 37 of Set 15 | brigantine
# Processing Record 38 of Set 15 | sarakhs
# Processing Record 39 of Set 15 | hasilpur
# Processing Record 40 of Set 15 | sain alto
# Processing Record 41 of Set 15 | zaraza
# Processing Record 42 of Set 15 | roma
# Processing Record 43 of Set 15 | kutum
# Processing Record 44 of Set 15 | lincoln
# Processing Record 45 of Set 15 | poum
# Processing Record 46 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 47 of Set 15 | rafraf
# Processing Record 48 of Set 15 | medina del campo
# Processing Record 49 of Set 15 | nizhniy ingash
# Processing Record 50 of Set 15 | tual
# Processing Record 1 of Set 16 | maloyaz
# City not found. Skipping...
# Processing Record 2 of Set 16 | proletarskiy
# Processing Record 3 of Set 16 | eureka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
